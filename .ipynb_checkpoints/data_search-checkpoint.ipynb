# %%
import torch, os
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
import pandas as pd
full = pd.read_csv("/home/joychou/急診ICU/full_dataset.csv")
train=pd.read_csv("/home/joychou/急診ICU/original_train_val.csv")
test=pd.read_csv("/home/joychou/急診ICU/original_test.csv")
icu=pd.read_csv("/home/joychou/急診ICU/icustays.csv")
items=pd.read_csv("/home/joychou/急診ICU/d_items.csv")
procedureevents=pd.read_csv("/home/joychou/急診ICU/procedureevents.csv")
#radiology=pd.read_csv("/home/joychou/急診ICU/radiology.csv")
